# %%
import numpy as numpy
from PIL import Image, ImageDraw
import tkinter as tk
from tensorflow.keras.models import load_model

# %%
model = load_model('/Users/s932172@aics.espritscholen.nl/Desktop/game development/deep_learning/lesson_2/digit_recognition_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
class DigitRecognizerApp:
    def __init__(self, model):
        self.window = model.selfwindow = tk.Tk()
        self.window.title("Handwritten Digit Recognizer")

        self.canvas = tk.Canvas(self.window, width=200, height=200, bg='white')
        self.canvas.grid(row=0, column=0, pady=2, padx=2)
        self.canvas.bind("<B1-Motion>", self.draw)

        self.label = tk.Label(self.window, text="Draw a digit", font=("Arial", 24))
        self.label.grid(row=0,column=1, padx=2, pady=2)

        self.clear_button = tk.Button(self.window, text="Clear", command=self.clear_canvas)
        self.clear_button.grid(row=1, column=0, padx=2, pady=2)
        
        self.predict_button = tk.Button(self.window, text="Predict")
        self.predict_button.grid(row=1, column=1, padx=2, pady=2)

        self.image = Image.new("L", (200,200), color="white")
        self.draw_obj = ImageDraw.Draw(self.image)

    def draw(self, event):
        print('drawing')
        x, y = event.x, event.y

        
        # self.canvas.create_oval(x-8, y-8, x+8, y+8, fill='black', outline='black')
        self.draw_obj.ellipse([x-8,y-8,x+8,y+8], fill=0)


    def clear_canvas(self):
        self.canvas.delete("all")
        self.image = Image.new("L", (200,200), color="white")
        self.draw_obj = ImageDraw.Draw(self.image)
        self.label.config(text='Draw a digit')

    def predict_digit(self):
        img = self.image.resize((28,28))

        img.np.array(img) / 255.0

        img = np.expand_dims(img, axis=0)

        prediction = self.model.predict(img)

        digit = np.argmax(prediction)

        self.label.config(text=f"Prediction {digit}")

    def run(self):
        self.window.mainloop()

app = DigitRecognizerApp(model)
app.run()
# Out:
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# drawing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 54
#      51         self.window.mainloop()
#      53 app = DigitRecognizerApp(model)
# ---> 54 app.run()
#
# Cell In[6], line 51, in DigitRecognizerApp.run(self)
#      50 def run(self):
# ---> 51     self.window.mainloop()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/tkinter/__init__.py:1429, in Misc.mainloop(self, n)
#    1427 def mainloop(self, n=0):
#    1428     """Call the mainloop of Tk."""
# -> 1429     self.tk.mainloop(n)
#
# KeyboardInterrupt:
